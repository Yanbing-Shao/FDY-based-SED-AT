# %%
import yaml
import h5py
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from loguru import logger as lg
from termcolor import colored

# %% [markdown]
# ### Open conf file

# %%
with open("../config/sed_16k.yaml", "r") as f:
    conf = yaml.safe_load(f)

# %%
conf["data"]
# Out:
# {'audio_max_len': 10,
#  'fs': 16000,
#  'net_subsample': 4,
#  'root_path': '/home/tianzichen/SELDProjects/CoSMo/data/',
#  'hdf5_train': 'train_16k.h5',
#  'hdf5_val': 'val_16k.h5',
#  'hdf5_test': 'test_16k.h5',
#  'sonyc_csv_train': 'metadata/train/SONYC_train.csv',
#  'sonyc_csv_val': 'metadata/val/SONYC_val.csv',
#  'sonyc_csv_test': 'metadata/test/SONYC_test.csv',
#  'raw_singa-pura_csv_root': '/home/tianzichen/sound_datasets/singapura/labels_public',
#  'singa-pura_csv_train': 'metadata/train/SINGA-PURA_train.csv',
#  'singa-pura_csv_val': 'metadata/val/SINGA-PURA_val.csv',
#  'singa-pura_csv_test': 'metadata/test/SINGA-PURA_test.csv',
#  'singa-pura_csv_unlabelled': 'metadata/train/SINGA-PURA_unlabelled.csv',
#  'taxonomy_path': '/home/tianzichen/SELDProjects/CoSMo/config/taxonomy_SINGA-PURA.yaml'}

# %%
def print_hf(hf_path):
    hf = h5py.File(hf_path)

    def recursive_print(hf, tab):
        for name in hf:
            if isinstance(hf[name], h5py.Group):
                print("".join(["\t"] * tab) + name)
                recursive_print(hf[name], tab + 1)
            else:
                print(
                    "".join(["\t"] * tab) + str(hf[name]).replace("<HDF5 dataset", "")
                )

    recursive_print(hf, 0)

# %%
print_hf("../data/val_16k.h5")
# Out:
# SINGA-PURA
# 	 "audio_32k": shape (736, 160000), type "<f4">
# 	 "filenames": shape (736,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (736, 15, 78), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (736, 8, 78), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (736, 50, 78), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (736, 29, 78), type "<f8">
# SONYC
# 	 "audio_32k": shape (538, 160000), type "<f4">
# 	 "filenames": shape (538,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (538, 15), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (538, 8), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (538, 50), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (538, 29), type "<f8">

# %%
print_hf("../data/train.h5")
# Out:
# SINGA-PURA
# 	 "audio_32k": shape (4435, 160000), type "<f4">
# 	 "filenames": shape (4435,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (4435, 15, 78), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (4435, 8, 78), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (4435, 50, 78), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (4435, 29, 78), type "<f8">
# SONYC
# 	 "audio_32k": shape (12978, 160000), type "<f4">
# 	 "filenames": shape (12978,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (12978, 15), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (12978, 8), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (12978, 50), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (12978, 29), type "<f8">
# unlabelled_SINGA-PURA
# 	 "audio_32k": shape (30001, 160000), type "<f4">
# 	 "filenames": shape (30001,), type "|O">

# %%
print_hf(os.path.join(conf["data"]["root_path"], "test_16k.h5"))
# Out:
# SINGA-PURA
# 	 "audio_32k": shape (1376, 160000), type "<f4">
# 	 "filenames": shape (1376,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (1376, 15, 78), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (1376, 8, 78), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (1376, 50, 78), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (1376, 29, 78), type "<f8">
# SONYC
# 	 "audio_32k": shape (664, 160000), type "<f4">
# 	 "filenames": shape (664,), type "|O">
# 	groundtruth
# 		 "taxonomy_coarse_SINGA-PURA": shape (664, 15), type "<f8">
# 		 "taxonomy_coarse_SONYC": shape (664, 8), type "<f8">
# 		 "taxonomy_fine_SINGA-PURA": shape (664, 50), type "<f8">
# 		 "taxonomy_fine_SONYC": shape (664, 29), type "<f8">

# %%
hf.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb 单元格 9 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> hf.close()
#
# NameError: name 'hf' is not defined

# %%
@lg.catch
def clone_hdf5(hdf5_file_path, new_hdf5_file_path, ignore_dataset_names=[]):
    hdf5_file = h5py.File(hdf5_file_path, "r")
    new_hdf5_file = h5py.File(new_hdf5_file_path, "w-")

    def recursive_clone(src, tgt, ignore_dataset_names, tab=0):
        for name in src:
            if isinstance(src[name], h5py.Group):
                print(colored("".join(["\t"] * tab) + name, attrs=["bold"]))
                tgt.create_group(name)
                recursive_clone(src[name], tgt[name], ignore_dataset_names, tab + 1)
            else:
                print(
                    colored(
                        "".join(["\t"] * tab)
                        + str(src[name]).replace("<HDF5 dataset", ""),
                        "red",
                    )
                )
                if name not in ignore_dataset_names:
                    src.copy(src[name], tgt)

    recursive_clone(hdf5_file, new_hdf5_file, ignore_dataset_names)

    hdf5_file.close()
    new_hdf5_file.close()

# %%
root_path = conf["data"]["root_path"]
cloned_path = os.path.join(root_path, "cloned")
to_clone = "test.h5"

# %%
ignore_dataset_names = ["open_l3_6144", "open_l3_512", "audio_32k", "passt_2levelmel"]
clone_hdf5(
    os.path.join(root_path, to_clone),
    os.path.join(cloned_path, to_clone),
    ignore_dataset_names,
)
# Out:
# 2025-03-25 21:42:07.190 | ERROR    | __main__:<cell line: 2>:2 - An error has been caught in function '<cell line: 2>', process 'MainProcess' (6367), thread 'MainThread' (140637101754176):
# Traceback (most recent call last):
#
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7fe89f148b30, file "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel_la...
#            └ <function _run_code at 0x7fe89f155ca0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7fe89f148b30, file "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel_la...
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/traitlets/config/application.py", line 1046, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7fe89c8478b0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7fe8a06f71c0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7fe89c80a430>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7fe89c817160>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7fe8a06f71c0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7fe89e5bc0d0>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7fe89c817160>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7fe89e5bec10>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7fe89e5ff700>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7fe89da881c0>(<Future finis...ca0>, ...],))>)>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle <TaskWakeupMethWrapper object at 0x7fe89da881c0>(<Future finis...ca0>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle <TaskWakeupMethWrapper object at 0x7fe89da881c0>(<Future finis...ca0>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle <TaskWakeupMethWrapper object at 0x7fe89da881c0>(<Future finis...ca0>, ...],))>)>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x7fe89cd9af70>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x7fe89c817fa0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.sugar.frame.Frame object at 0x7fe89eb497d0>, <zmq.sugar.frame.Frame object at 0x7fe89eb4df60>, <zmq.sugar.frame.Frame ...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7fe89c817fa0>>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#           └ <coroutine object Kernel.execute_request at 0x7fe84a5b5b40>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x7fe84a7c7f40>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7fe89c83a160>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell:/home/tianzichen/SELDProjects/CoSMo/notebooks/proce...
#                              └ ('ignore_dataset_names = ["open_l3_6144", "open_l3_512", "audio_32k", "passt_2levelmel"]\nclone_hdf5(\n    os.path.join(root_...
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7fe89d75d4c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7fe84a7c7cc0>
#            └ <function _pseudo_sync_runner at 0x7fe89d932ee0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7fe84a7c7cc0>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_6367/3643920716.py'
#                        │    │             │        └ [<_ast.Assign object at 0x7fe89da8e7f0>, <_ast.Expr object at 0x7fe89da9f5b0>]
#                        │    │             └ <_ast.Module object at 0x7fe89da8e040>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7fe89d75d820>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 7fe84a2d8bb0, execution_count=10 error_before_exec=None error_in_exec=None info=<ExecutionInfo obj...
#              │    │        └ <code object <cell line: 2> at 0x7fe8987e6ea0, file "/tmp/ipykernel_6367/3643920716.py", line 2>
#              │    └ <function InteractiveShell.run_code at 0x7fe89d75d8b0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#          │         │    └ <property object at 0x7fe89d9401d0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fe89c820550>
#          └ <code object <cell line: 2> at 0x7fe8987e6ea0, file "/tmp/ipykernel_6367/3643920716.py", line 2>
#
# > File "/tmp/ipykernel_6367/3643920716.py", line 2, in <cell line: 2>
#     clone_hdf5(
#     └ <function clone_hdf5 at 0x7fe84a778550>
#
#   File "/tmp/ipykernel_6367/4142341539.py", line 4, in clone_hdf5
#     new_hdf5_file = h5py.File(new_hdf5_file_path, "w-")
#                     │    │    └ '/home/tianzichen/SELDProjects/CoSMo/data/cloned/test.h5'
#                     │    └ <class 'h5py._hl.files.File'>
#                     └ <module 'h5py' from '/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/h5py/__init__.py'>
#
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/h5py/_hl/files.py", line 424, in __init__
#     fid = make_fid(name, mode, userblock_size,
#           │        │     │     └ None
#           │        │     └ 'w-'
#           │        └ b'/home/tianzichen/SELDProjects/CoSMo/data/cloned/test.h5'
#           └ <function make_fid at 0x7fe84aa20790>
#   File "/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/h5py/_hl/files.py", line 194, in make_fid
#     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#           │   │      │     │   │              │          └ None
#           │   │      │     │   │              └ <h5py.h5p.PropFAID object at 0x7fe84a59c3b0>
#           │   │      │     │   └ 4
#           │   │      │     └ <module 'h5py.h5f' from '/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/h5py/h5f.cpython-38-x86_64-linux-g...
#           │   │      └ b'/home/tianzichen/SELDProjects/CoSMo/data/cloned/test.h5'
#           │   └ <cyfunction create at 0x7fe84c40f520>
#           └ <module 'h5py.h5f' from '/home/tianzichen/anaconda3/envs/CoSMo/lib/python3.8/site-packages/h5py/h5f.cpython-38-x86_64-linux-g...
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 116, in h5py.h5f.create
#
# OSError: Unable to create file (unable to open file: name = '/home/tianzichen/SELDProjects/CoSMo/data/cloned/test.h5', errno = 2, error message = 'No such file or directory', flags = 15, o_flags = c2)

# %%
import openl3
import numpy as np
from tqdm import tqdm


def compute_l3_embeddings(hf_path):
    hf = h5py.File(hf_path, "r+")
    model = openl3.models.load_audio_embedding_model(
        input_repr="mel256", content_type="env", embedding_size=512, frontend="kapre"
    )
    if "train_hear.h5" in hf_path:
        hf_audio = h5py.File(hf_path.replace("_hear", ""), "r")
    else:
        hf_audio = hf

    for dname in ["SONYC", "SINGA-PURA"]:
        print(dname)
        audio_dset = hf_audio[dname]["audio_32k"]
        dset_size = audio_dset.shape[0]
        embed_dset = hf[dname].require_dataset(
            "open_l3_512", shape=(dset_size, 96, 512), dtype="float32"
        )
        for i in tqdm(range(dset_size)):
            embed_dset[i], _ = openl3.get_audio_embedding(
                audio_dset[i], 32000, model=model, batch_size=96, verbose=False
            )

# %%
for hf_name in ["train_hear.h5", "val.h5", "test.h5"]:
    print(hf_name)
    compute_l3_embeddings(os.path.join(root_path, hf_name))
# Out:
# train_hear.h5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb 单元格 12 line <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> for hf_name in ["train_hear.h5", "val.h5", "test.h5"]:
#       <a href='vscode-notebook-cell:/home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     print(hf_name)
# ----> <a href='vscode-notebook-cell:/home/tianzichen/SELDProjects/CoSMo/notebooks/process_hdf5.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     compute_l3_embeddings(os.path.join(root_path, hf_name))
#
# NameError: name 'compute_l3_embeddings' is not defined
